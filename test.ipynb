# %%
import pandas as pd

# %%
pd.read_csv("data/big_west_inbound_transfers_needs_review.csv")
# Out:
#              player_name          player_slug destination_school_slug  \
# 0           Abass Bodija         abass-bodija            uc-riverside
# 1       Aboubacar Traoré      aboubacar-traor        long-beach-state
# 2           Akira Jacobs         akira-jacobs                  hawaii
# 3            Andrew Nagy          andrew-nagy        long-beach-state
# 4        Antwan Robinson      antwan-robinson     cal-state-fullerton
# 5            Ariel Bland          ariel-bland        uc-santa-barbara
# 6    Barrington Hargress  barrington-hargress            uc-riverside
# 7          Bryan Ndjonga        bryan-ndjonga    cal-state-northridge
# 8         Carter Welling       carter-welling               uc-irvine
# 9            Davis Bynum          davis-bynum     cal-state-fullerton
# 10           Derin Saran          derin-saran               uc-irvine
# 11         Emilis Butkus        emilis-butkus               uc-irvine
# ...
